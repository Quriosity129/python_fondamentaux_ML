# %% [markdown]
# On reste sur l'analyse du jeu de données `artere.txt`. Importons les packages nécessaires et chargeons ensuite ces données dans un dataframe :

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/sample_data/artere.txt", header=0, sep=" ")

# %% [markdown]
# 1. Implémenter une régression logistique avec `chd` comme cible et `age` comme variable explicative.

# %% [markdown]
# 2. Afficher les paramètres de régression estimés par le modèle.

# %% [markdown]
# 3. Afficher la prévision pour les données de test via la méthode `predict_proba`. Que représente le résultat ?
#
#  * une probabilité d'être malade pour chaque âge dans l'échantillon ;
#  * une probabilité d'être malade et non-malade pour chaque âge dans l'échantillon ;
#  * une probabilité d'être non-malade et malade pour chaque âge dans l'échantillon ;
#  * une prévision de l'état malade/non-malade pour chaque âge dans l'échantillon.

# %% [markdown]
# 4. Afficher la prévision des états des patients (malade/non-malade) pour un seuil de probabilité de 0.4.

# %% [markdown]
# 5. Calculer et afficher la matrice de confusion sur les données de test. Utiliser pour cela les fonctions `confusion_matrix` et `ConfusionMatrixDisplay` de `sklearn.metrics`. Choisir un seuil de 0,5 pour la prédiction des labels.

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# Calculons à présent quelques métriques de performance.

# %% [markdown]
# 6. Calculer la précision et le rappel du modèle.

# %% [markdown]
# 7. Quelles seraient la précision et le rappel d'un modèle agnostique (c'est-à-dire sans variables explicatives ?)
